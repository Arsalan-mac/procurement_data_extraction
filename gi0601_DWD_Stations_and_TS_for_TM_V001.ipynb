# %% [markdown]
# # Read DWD CDC Time Series, Merge with Station Description and Append
#
# The main idea behind this activity is to reformat and merge time series (here we use hourly precipitation) from the DWD Climate Data Center in such a way that it can be used with the **QGIS time manager extension**.
#
# This extension allows to filter an attribute table of a vector layer (e.g. points representing precipitation stations plus precipitation data) with a time stamp column. The extension limits the attribute table to the records matching the particular time stamp provided by the time manager extension (e.g. by the user moving the time slider). This selected subset of the attribute table is then used to change the sympology of the vector layer according to the variable of interest (e.g. precipitation rate).
#
# The QGIS time manager extension approach is a bit brute force, because each individual measurement at a station at a given time is one feature (row in the table), i.e. a time series at station X with hourly resolution for a day (24 values) entails 24 different features with the same station id and the corresponding coordinates but different times. As of now this 1:n relationship can only be realized by importing a CSV file with the according structure.
#
# (At least I was not able to generate the required view on a 1:n relationship by merging a point vector layer with precipitation station locations and an imported CSV time series table.)
#
# The final data format is a concatenation of time series together with geographic location in 2D (e.g. lat, lon). The required data format looks principly like this:
#
#
# | station_id |        name        |   lat   |   lon  |        meas_time       | prec_rate |
# |:----------:|:------------------:|:-------:|:------:|:----------------------:|:---------:|
# |        ... | ...                |     ... |    ... |                    ... |       ... |
# |       1595 | Gelsenkirchen-Buer | 51.5762 | 7.0652 | 2018-12-07T08:00:00UTC |       1.5 |
# |       1595 | Gelsenkirchen-Buer | 51.5762 | 7.0652 | 2018-12-07T09:00:00UTC |       1.7 |
# |       1595 | Gelsenkirchen-Buer | 51.5762 | 7.0652 | 2018-12-07T10:00:00UTC |       0.1 |
# |        ... | ...                |     ... |    ... |                    ... |       ... |
# |      13670 | Duisburg-Baerl     | 51.5088 | 6.7018 | 2018-12-07T08:00:00UTC |       0.8 |
# |      13670 | Duisburg-Baerl     | 51.5088 | 6.7018 | 2018-12-07T09:00:00UTC |       0.4 |
# |      13670 | Duisburg-Baerl     | 51.5088 | 6.7018 | 2018-12-07T10:00:00UTC |       0.0 |
# |        ... | ...                |     ... |    ... |                    ... |       ... |
#
#
# (Table generated with https://www.tablesgenerator.com/markdown_tables)
#
# To achieve this the precipitation time series (station_id, meas_time, prec_rate) have to be merged with the station metadata (station_id, lat, lon) coming from the a CSV file generated in an earlier activity. We use Pandas to read, join and append the data to generate the final CSV file to be imported as a point layer to QGIS.
#
# This final data format is far from being optimal because of large size and highly redundant information. This is a challenge for QGIS which loses responsiveness with large data. To jsut show the principle it is advisable to limit to size of the problem.
#
# The following filters (selection criteria) are applied:
#
#   * Precipitation stations in NRW only (approx. 127 stations)
#   * Hourly precipitation data
#   * Time interval from 2018-12-01 to last date in precipitation data set
#
# Still: 40 days * 24 hrs / day * 127 stations = 121920 records leading to 121920 features in a point layer in QGIS.
#
# In fact, the resulting number of records is arround 91000. The reason might be that not all stations in the station list have time series. This has to be checked carefully.

# %% [markdown]
# ## FTP Connection

# %% [markdown]
# ### Connection Parameters

# %%
server = "opendata.dwd.de"
user   = "anonymous"
passwd = ""

# %% [markdown]
# ### FTP Directory Definition and Station Description Filename Pattern

# %%
# The topic of interest.
topic_dir = "/daily/more_precip/historical/"
#topic_dir = "/annual/kl/historical/"

# This is the search pattern common to ALL station description file names 
station_desc_pattern = "_Beschreibung_Stationen.txt"

# Below this directory tree node all climate data are stored.
ftp_climate_data_dir = "/climate_environment/CDC/observations_germany/climate/"
ftp_dir =  ftp_climate_data_dir + topic_dir

# %% [markdown]
# ### Local Directories

# %%
local_ftp_dir         = "data/original/DWD/"      # Local directory to store local ftp data copies, the local data source or input data. 
local_ftp_station_dir = local_ftp_dir + topic_dir # Local directory where local station info is located
local_ftp_ts_dir      = local_ftp_dir + topic_dir # Local directory where time series downloaded from ftp are located

local_generated_dir   = "data/generated/DWD/" # The generated of derived data in contrast to local_ftp_dir
local_station_dir     = local_generated_dir + topic_dir # Derived station data, i.e. the CSV file
local_ts_merged_dir   = local_generated_dir + topic_dir # Parallel merged time series, wide data frame with one TS per column
local_ts_appended_dir = local_generated_dir + topic_dir # Serially appended time series, long data frame for QGIS TimeManager Plugin

# %%
print(local_ftp_dir)
print(local_ftp_station_dir)
print(local_ftp_ts_dir)
print()
print(local_generated_dir)
print(local_station_dir)
print(local_ts_merged_dir)
print(local_ts_appended_dir)
# Out:
# data/original/DWD/
# data/original/DWD//daily/more_precip/historical/
# data/original/DWD//daily/more_precip/historical/
#
# data/generated/DWD/
# data/generated/DWD//daily/more_precip/historical/
# data/generated/DWD//daily/more_precip/historical/
# data/generated/DWD//daily/more_precip/historical/

# %%
import os
os.makedirs(local_ftp_dir,exist_ok = True) # it does not complain if the dir already exists.
os.makedirs(local_ftp_station_dir,exist_ok = True)
os.makedirs(local_ftp_ts_dir,exist_ok = True)

os.makedirs(local_generated_dir,exist_ok = True)
os.makedirs(local_station_dir,exist_ok = True)
os.makedirs(local_ts_merged_dir,exist_ok = True)
os.makedirs(local_ts_appended_dir,exist_ok = True)

# %% [markdown]
# ### FTP Connect

# %%
import ftplib
ftp = ftplib.FTP(server)
res = ftp.login(user=user, passwd = passwd)
print(res)
# Out:
# 230 Login successful.

# %%
ret = ftp.cwd(".")

# %%
#ftp.quit()

# %% [markdown]
# ### FTP Grab File Function

# %%
def grabFile(ftpfullname,localfullname):
    try:
        ret = ftp.cwd(".") # A dummy action to chack the connection and to provoke an exception if necessary.
        localfile = open(localfullname, 'wb')
        ftp.retrbinary('RETR ' + ftpfullname, localfile.write, 1024)
        localfile.close()
    
    except ftplib.error_perm:
        print("FTP ERROR. Operation not permitted. File not found?")

    except ftplib.error_temp:
        print("FTP ERROR. Timeout.")

    except ConnectionAbortedError:
        print("FTP ERROR. Connection aborted.")

# %% [markdown]
# ### Generate Pandas Dataframe from FTP Directory Listing

# %%
import pandas as pd
import os

def gen_df_from_ftp_dir_listing(ftp, ftpdir):
    lines = []
    flist = []
    try:    
        res = ftp.retrlines("LIST "+ftpdir, lines.append)
    except:
        print("Error: ftp.retrlines() failed. ftp timeout? Reconnect!")
        return
        
    if len(lines) == 0:
        print("Error: ftp dir is empty")
        return
    
    for line in lines:
#        print(line)
        [ftype, fsize, fname] = [line[0:1], int(line[31:42]), line[56:]]
#        itemlist = [line[0:1], int(line[31:42]), line[56:]]
#        flist.append(itemlist)
        
        fext = os.path.splitext(fname)[-1]
        
        if fext == ".zip":
            station_id = int(fname.split("_")[2])
        else:
            station_id = -1 
        
        flist.append([station_id, fname, fext, fsize, ftype])
        
        

    df_ftpdir = pd.DataFrame(flist,columns=["station_id", "name", "ext", "size", "type"])
    return(df_ftpdir)

# %%
df_ftpdir = gen_df_from_ftp_dir_listing(ftp, ftp_dir)

# %%
df_ftpdir.head()
# Out:
#    station_id                                               name   ext  \
# 0          -1  BESCHREIBUNG_obsgermany_climate_daily_more_pre...  .pdf
# 1          -1  DESCRIPTION_obsgermany_climate_daily_more_prec...  .pdf
# 2          -1           RR_Tageswerte_Beschreibung_Stationen.txt  .txt
# 3           1     tageswerte_RR_00001_19120101_19860630_hist.zip  .zip
# 4           2     tageswerte_RR_00002_19510101_20061231_hist.zip  .zip
#
#       size type
# 0    72261    -
# 1    71026    -
# 2  1202717    -
# 3   113547    -
# 4    85314    -

# %% [markdown]
# ### Dataframe with TS Zip Files

# %%
#df_ftpdir["ext"]==".zip"
df_zips = df_ftpdir[df_ftpdir["ext"]==".zip"]
df_zips.set_index("station_id", inplace = True)
df_zips.head()
# Out:
#                                                       name   ext    size type
# station_id
# 1           tageswerte_RR_00001_19120101_19860630_hist.zip  .zip  113547    -
# 2           tageswerte_RR_00002_19510101_20061231_hist.zip  .zip   85314    -
# 3           tageswerte_RR_00003_18910101_20110331_hist.zip  .zip  172281    -
# 4           tageswerte_RR_00004_19510101_19791031_hist.zip  .zip   47378    -
# 6           tageswerte_RR_00006_19821101_20191231_hist.zip  .zip   51877    -

# %% [markdown]
# ### Download the Station Description File

# %%
station_fname = df_ftpdir[df_ftpdir['name'].str.contains(station_desc_pattern)]["name"].values[0]
print(station_fname)

# ALternative
#station_fname2 = df_ftpdir[df_ftpdir["name"].str.match("^.*Beschreibung_Stationen.*txt$")]["name"].values[0]
#print(station_fname2)
# Out:
# RR_Tageswerte_Beschreibung_Stationen.txt

# %%
print("grabFile: ")
print("From: " + ftp_dir + station_fname)
print("To:   " + local_ftp_station_dir + station_fname)
grabFile(ftp_dir + station_fname, local_ftp_station_dir + station_fname)
# Out:
# grabFile:
# From: /climate_environment/CDC/observations_germany/climate//daily/more_precip/historical/RR_Tageswerte_Beschreibung_Stationen.txt
# To:   data/original/DWD//daily/more_precip/historical/RR_Tageswerte_Beschreibung_Stationen.txt

# %%
# extract column names. They are in German (de)
# We have to use codecs because of difficulties with character encoding (German Umlaute)
import codecs

def station_desc_txt_to_csv(txtfile, csvfile):
    file = codecs.open(txtfile,"r","utf-8")
    r = file.readline()
    file.close()
    colnames_de = r.split()
    colnames_de
    
    translate = \
    {'Stations_id':'station_id',
     'von_datum':'date_from',
     'bis_datum':'date_to',
     'Stationshoehe':'altitude',
     'geoBreite': 'latitude',
     'geoLaenge': 'longitude',
     'Stationsname':'name',
     'Bundesland':'state'}
    
    colnames_en = [translate[h] for h in colnames_de]
    
    # Skip the first two rows and set the column names.
    df = pd.read_fwf(txtfile,skiprows=2,names=colnames_en, parse_dates=["date_from","date_to"],index_col = 0)
    
    # write csv
    df.to_csv(csvfile, sep = ";")
    return(df)

# %%
basename = os.path.splitext(station_fname)[0]
df_stations = station_desc_txt_to_csv(local_ftp_station_dir + station_fname, local_station_dir + basename + ".csv")
df_stations.head()
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 1          1912-01-01 1986-06-30       478   47.8413     8.8493
# 2          1951-01-01 2006-12-31       138   50.8066     6.0996
# 3          1891-01-01 2011-03-31       202   50.7827     6.0941
# 4          1951-01-01 1979-10-31       243   50.7683     6.1207
# 6          1982-11-01 2020-06-30       455   48.8361    10.0598
#
#                            name                state
# station_id
# 1                          Aach    Baden-Württemberg
# 2           Aachen (Kläranlage)  Nordrhein-Westfalen
# 3                        Aachen  Nordrhein-Westfalen
# 4                  Aachen-Brand  Nordrhein-Westfalen
# 6            Aalen-Unterrombach    Baden-Württemberg

# %% [markdown]
# ### Select Stations Located in NRW from Station Description Dataframe

# %%
isOperational = df_stations.date_to.max() 

station_ids_selected = df_stations[df_stations['state'].str.contains("Bayern")].index 
station_ids_selected
#isOperational
# Out:
# Int64Index([   10,    15,    16,    17,    24,    27,    29,    37,    46,
#                48,
#             ...
#             15930, 15943, 15945, 15953, 15965, 15977, 19087, 19120, 19127,
#             19128],
#            dtype='int64', name='station_id', length=1298)

# %%
# Create variable with TRUE if state is Nordrhein-Westfalen
isNRW = df_stations['state'] == "Bayern"

# Create variable with TRUE if date_to is latest date (indicates operation up to now)
isOperational = df_stations['date_to'] == df_stations.date_to.max() 

isBefore1950 = df_stations['date_from'] < '1980'


# select on both conditions
dfNRW = df_stations[isNRW & isOperational & isBefore1950]

#print("Number of stations in NRW: \n", dfNRW.count())
dfNRW
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 29         1951-01-01 2020-06-30       260   49.7175    10.9101
# 46         1941-01-01 2020-06-30       325   48.9450    12.4639
# 55         1951-01-01 2020-06-30       509   47.8780    12.0239
# 57         1978-01-01 2020-06-30       461   48.4799    11.0521
# 63         1951-01-01 2020-06-30       747   47.8172    10.5374
# ...               ...        ...       ...       ...        ...
# 5941       1899-01-01 2020-06-30       686   47.6754    12.4698
# 6284       1941-01-01 2020-06-30       420   49.2289    10.5044
# 6295       1931-01-01 2020-06-30       650   47.8030    11.8250
# 7369       1931-01-01 2020-06-30       475   49.1623    10.3661
# 14670      1941-01-01 2020-06-30       383   48.8777    11.8903
#
#                                    name   state
# station_id
# 29               Adelsdorf (Kläranlage)  Bayern
# 46                             Aholfing  Bayern
# 55                Aibling, Bad-Ellmosen  Bayern
# 57          Hollenbach/Bayern-Schönbach  Bayern
# 63                              Aitrang  Bayern
# ...                                 ...     ...
# 5941                      Reit im Winkl  Bayern
# 6284             Herrieden (Kläranlage)  Bayern
# 6295              Miesbach (Kläranlage)  Bayern
# 7369             Feuchtwangen-Heilbronn  Bayern
# 14670                  Kelheim-Thaldorf  Bayern
#
# [417 rows x 7 columns]

# %%
print(df_zips)
# Out:
#                                                       name   ext    size type
# station_id
# 1           tageswerte_RR_00001_19120101_19860630_hist.zip  .zip  113547    -
# 2           tageswerte_RR_00002_19510101_20061231_hist.zip  .zip   85314    -
# 3           tageswerte_RR_00003_18910101_20110331_hist.zip  .zip  172281    -
# 4           tageswerte_RR_00004_19510101_19791031_hist.zip  .zip   47378    -
# 6           tageswerte_RR_00006_19821101_20191231_hist.zip  .zip   51877    -
# ...                                                    ...   ...     ...  ...
# 19096       tageswerte_RR_19096_19530401_20020630_hist.zip  .zip   73802    -
# 19120       tageswerte_RR_19120_20190701_20190923_hist.zip  .zip    9475    -
# 19123       tageswerte_RR_19123_20190701_20191231_hist.zip  .zip  294489    -
# 19125       tageswerte_RR_19125_20190901_20191231_hist.zip  .zip    7462    -
# 19127       tageswerte_RR_19127_20191001_20191231_hist.zip  .zip    7350    -
#
# [5600 rows x 4 columns]

# %% [markdown]
# ### Download TS Data from FTP Server
#
# Problem: Not all stations listed in the station description file are associated with a time series (zip file)! The stations in the description file and the set of stations whoch are TS data provided for (zip files) do not match perfectly.

# %%
list(dfNRW.index)
# Out:
# [29,
#  46,
#  55,
#  57,
#  63,
#  103,
#  118,
#  128,
#  142,
#  145,
#  146,
#  151,
#  160,
#  163,
#  202,
#  203,
#  205,
#  217,
#  223,
#  227,
#  232,
#  262,
#  282,
#  318,
#  319,
#  320,
#  323,
#  349,
#  359,
#  360,
#  376,
#  447,
#  475,
#  509,
#  515,
#  516,
#  522,
#  552,
#  562,
#  572,
#  606,
#  647,
#  653,
#  734,
#  745,
#  759,
#  789,
#  801,
#  803,
#  807,
#  808,
#  811,
#  812,
#  851,
#  857,
#  867,
#  885,
#  922,
#  933,
#  952,
#  973,
#  983,
#  985,
#  1023,
#  1094,
#  1103,
#  1107,
#  1119,
#  1132,
#  1140,
#  1143,
#  1161,
#  1235,
#  1237,
#  1248,
#  1256,
#  1264,
#  1279,
#  1309,
#  1313,
#  1322,
#  1325,
#  1332,
#  1343,
#  1357,
#  1365,
#  1366,
#  1374,
#  1382,
#  1401,
#  1432,
#  1458,
#  1459,
#  1473,
#  1511,
#  1528,
#  1534,
#  1542,
#  1550,
#  1575,
#  1577,
#  1578,
#  1587,
#  1588,
#  1601,
#  1642,
#  1652,
#  1682,
#  1689,
#  1729,
#  1730,
#  1734,
#  1751,
#  1764,
#  1844,
#  1846,
#  1851,
#  1886,
#  1900,
#  1909,
#  1933,
#  1938,
#  1950,
#  1997,
#  2051,
#  2064,
#  2079,
#  2103,
#  2109,
#  2113,
#  2123,
#  2132,
#  2168,
#  2178,
#  2222,
#  2255,
#  2261,
#  2268,
#  2274,
#  2290,
#  2376,
#  2387,
#  2403,
#  2405,
#  2409,
#  2412,
#  2415,
#  2416,
#  2431,
#  2453,
#  2454,
#  2480,
#  2491,
#  2499,
#  2526,
#  2538,
#  2550,
#  2556,
#  2559,
#  2582,
#  2597,
#  2600,
#  2660,
#  2674,
#  2680,
#  2700,
#  2709,
#  2724,
#  2740,
#  2750,
#  2754,
#  2781,
#  2792,
#  2820,
#  2847,
#  2860,
#  2867,
#  2884,
#  2885,
#  2894,
#  2943,
#  3010,
#  3055,
#  3080,
#  3121,
#  3131,
#  3147,
#  3153,
#  3179,
#  3180,
#  3182,
#  3183,
#  3185,
#  3188,
#  3190,
#  3192,
#  3207,
#  3211,
#  3220,
#  3241,
#  3244,
#  3251,
#  3258,
#  3262,
#  3265,
#  3271,
#  3282,
#  3288,
#  3291,
#  3293,
#  3301,
#  3307,
#  3319,
#  3341,
#  3366,
#  3371,
#  3379,
#  3381,
#  3399,
#  3424,
#  3429,
#  3435,
#  3438,
#  3460,
#  3464,
#  3497,
#  3504,
#  3535,
#  3536,
#  3549,
#  3550,
#  3560,
#  3571,
#  3572,
#  3607,
#  3617,
#  3621,
#  3667,
#  3668,
#  3670,
#  3677,
#  3679,
#  3681,
#  3682,
#  3685,
#  3687,
#  3689,
#  3700,
#  3703,
#  3710,
#  3711,
#  3714,
#  3722,
#  3723,
#  3729,
#  3730,
#  3731,
#  3737,
#  3739,
#  3746,
#  3765,
#  3772,
#  3799,
#  3810,
#  3835,
#  3836,
#  3849,
#  3875,
#  3878,
#  3886,
#  3901,
#  3907,
#  3919,
#  3926,
#  3930,
#  3934,
#  3948,
#  3960,
#  3962,
#  3972,
#  4000,
#  4016,
#  4064,
#  4065,
#  4086,
#  4103,
#  4104,
#  4106,
#  4107,
#  4109,
#  4159,
#  4165,
#  4185,
#  4218,
#  4224,
#  4248,
#  4251,
#  4261,
#  4284,
#  4287,
#  4297,
#  4298,
#  4319,
#  4374,
#  4377,
#  4387,
#  4392,
#  4413,
#  4441,
#  4482,
#  4493,
#  4494,
#  4515,
#  4516,
#  4528,
#  4546,
#  4548,
#  4554,
#  4579,
#  4592,
#  4599,
#  4603,
#  4607,
#  4609,
#  4615,
#  4617,
#  4641,
#  4675,
#  4694,
#  4697,
#  4706,
#  4754,
#  4755,
#  4759,
#  4760,
#  4808,
#  4816,
#  4824,
#  4827,
#  4850,
#  4858,
#  4865,
#  4911,
#  4946,
#  4949,
#  4954,
#  4958,
#  4990,
#  5000,
#  5002,
#  5015,
#  5017,
#  5023,
#  5036,
#  5046,
#  5054,
#  5055,
#  5065,
#  5073,
#  5111,
#  5123,
#  5141,
#  5149,
#  5160,
#  5161,
#  5162,
#  5167,
#  5169,
#  5176,
#  5187,
#  5216,
#  5218,
#  5227,
#  5230,
#  5262,
#  5276,
#  5285,
#  5303,
#  5336,
#  5364,
#  5370,
#  5374,
#  5376,
#  5389,
#  5397,
#  5399,
#  5404,
#  5405,
#  5432,
#  5440,
#  5444,
#  5470,
#  5485,
#  5487,
#  5501,
#  5548,
#  5573,
#  5597,
#  5599,
#  5600,
#  5615,
#  5650,
#  5658,
#  5705,
#  5721,
#  5747,
#  5748,
#  5753,
#  5780,
#  5785,
#  5792,
#  5793,
#  5941,
#  6284,
#  6295,
#  7369,
#  14670]

# %%
# Add the names of the zip files only to a list. 
local_zip_list = []

station_ids_selected = list(dfNRW.index)

for station_id in station_ids_selected:
    try:
        fname = df_zips["name"][station_id]
        print(fname)
        grabFile(ftp_dir + fname, local_ftp_ts_dir + fname)
        local_zip_list.append(fname)
    except:
        print("WARNING: TS file for key %d not found in FTP directory." % station_id)
# Out:
# tageswerte_RR_00029_19510101_20191231_hist.zip
# tageswerte_RR_00046_19410101_20191231_hist.zip
# tageswerte_RR_00055_19510101_20191231_hist.zip
# tageswerte_RR_00057_19780101_20191231_hist.zip
# tageswerte_RR_00063_19510101_20191231_hist.zip
# tageswerte_RR_00103_19780101_20191231_hist.zip
# tageswerte_RR_00118_19510101_20191231_hist.zip
# tageswerte_RR_00128_19510101_20191231_hist.zip
# tageswerte_RR_00142_19550101_20191231_hist.zip
# tageswerte_RR_05793_19410101_20191231_hist.zip
# tageswerte_RR_05941_18990101_20191231_hist.zip
# WARNING: TS file for key 6284 not found in FTP directory.
# WARNING: TS file for key 6295 not found in FTP directory.
# tageswerte_RR_07369_19310101_20191231_hist.zip
# tageswerte_RR_14670_19410101_20191231_hist.zip

# %% [markdown]
# ### Join (Merge) the Time Series Columns
#
# https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

# %%
def prec_ts_to_df(fname):
    
    dateparse = lambda dates: [pd.datetime.strptime(str(d), '%Y%m%d') for d in dates]

    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse, na_values = [-999.0, -999])

    #df = pd.read_csv(fname, delimiter=";", encoding="iso8859_2",\
    #             index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse)
    
    # https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
    return(df)

# %%
#def temp_ts_to_df(fname):
    
#    dateparse = lambda dates: [pd.datetime.strptime(str(d), '%Y%m%d') for d in dates]

#    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM_BEGINN", parse_dates = ["MESS_DATUM_BEGINN"], date_parser = dateparse, na_values = [-999.0, -999])

    #df = pd.read_csv(fname, delimiter=";", encoding="iso8859_2",\
    #             index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse)
    
    # https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.
#    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
#    return(df)

# %%
from zipfile import ZipFile

# %%
def ts_merge():
    # Very compact code.
    df = pd.DataFrame()
    for elt in local_zip_list:
        ffname = local_ftp_ts_dir + elt
        print("Zip archive: " + ffname)
        with ZipFile(ffname) as myzip:
            # read the time series data from the file starting with "produkt"
            prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
            print("Extract product file: %s" % prodfilename)
            print()
            with myzip.open(prodfilename) as myfile:
                dftmp = prec_ts_to_df(myfile)
#                s = dftmp["r1"].rename(dftmp["stations_id"][0]).to_frame()
                s = dftmp["stations_id"].to_frame()
                # outer merge.
                df = pd.merge(df, s, left_index=True, right_index=True, how='outer')

    #df.index.names = ["year"]
    df.index.rename(name = "time", inplace = True)
    return(df)

# %%
#def prec_ts_merge():
    # Very compact code.
#    df = pd.DataFrame()
#    for elt in local_zip_list:
#        ffname = local_ftp_ts_dir + elt
#        print("Zip archive: " + ffname)
#        with ZipFile(ffname) as myzip:
            # read the time series data from the file starting with "produkt"
#            prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
#            print("Extract product file: %s" % prodfilename)
#            print()
#            with myzip.open(prodfilename) as myfile:
#                dftmp = temp_ts_to_df(myfile)
#                s = dftmp["ja_tt"].rename(dftmp["stations_id"][0]).to_frame()
                # outer merge.
#                df = pd.merge(df, s, left_index=True, right_index=True, how='outer')

    #df.index.names = ["year"]
#    df.index.rename(name = "time", inplace = True)
#    return(df)

# %%
df_merged_ts = ts_merge()
# Out:
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00029_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00029.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00046_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00046.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00055_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00055.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00057_19780101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19780101_20191231_00057.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00063_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00063.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00103_19780101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19780101_20191231_00103.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00118_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00118.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00128_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00128.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00142_19550101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19550101_20191231_00142.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00145_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00145.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00146_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00146.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00151_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00151.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00160_19710101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19710101_20191231_00160.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00163_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00163.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00202_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00202.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00203_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00203.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00205_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00205.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00217_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00217.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00223_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00223.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00227_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00227.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00232_19470101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19470101_20191231_00232.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00262_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00262.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00282_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00282.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00318_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00318.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00319_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00319.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00320_18790101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18790101_20191231_00320.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00323_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00323.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00349_18910901_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18910901_20191231_00349.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00359_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00359.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00360_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00360.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00376_18990101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18990101_20191231_00376.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00447_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00447.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00475_18990201_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18990201_20191231_00475.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00509_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00509.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00515_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00515.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00516_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00516.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00522_19780101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19780101_20191231_00522.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00552_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00552.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00562_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00562.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00572_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00572.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00606_19500101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19500101_20191231_00606.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00647_18990101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18990101_20191231_00647.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00653_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00653.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00734_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00734.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00745_19710101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19710101_20191231_00745.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00759_19610101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19610101_20191231_00759.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00789_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00789.txt
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00801_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00801.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_
19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_14670.txt

# %%
df_merged_ts.head()
# Out:
#             stations_id_x  stations_id_y  stations_id_x  stations_id_y  \
# time
# 1781-01-01            NaN            NaN            NaN            NaN
# 1781-01-02            NaN            NaN            NaN            NaN
# 1781-01-03            NaN            NaN            NaN            NaN
# 1781-01-04            NaN            NaN            NaN            NaN
# 1781-01-05            NaN            NaN            NaN            NaN
#
#             stations_id_x  stations_id_y  stations_id_x  stations_id_y  \
# time
# 1781-01-01            NaN            NaN            NaN            NaN
# 1781-01-02            NaN            NaN            NaN            NaN
# 1781-01-03            NaN            NaN            NaN            NaN
# 1781-01-04            NaN            NaN            NaN            NaN
# 1781-01-05            NaN            NaN            NaN            NaN
#
#             stations_id_x  stations_id_y  ...  stations_id_x  stations_id_y  \
# time                                      ...
# 1781-01-01            NaN            NaN  ...            NaN            NaN
# 1781-01-02            NaN            NaN  ...            NaN            NaN
# 1781-01-03            NaN            NaN  ...            NaN            NaN
# 1781-01-04            NaN            NaN  ...            NaN            NaN
# 1781-01-05            NaN            NaN  ...            NaN            NaN
#
#             stations_id_x  stations_id_y  stations_id_x  stations_id_y  \
# time
# 1781-01-01            NaN            NaN            NaN            NaN
# 1781-01-02            NaN            NaN            NaN            NaN
# 1781-01-03            NaN            NaN            NaN            NaN
# 1781-01-04            NaN            NaN            NaN            NaN
# 1781-01-05            NaN            NaN            NaN            NaN
#
#             stations_id_x  stations_id_y  stations_id_x  stations_id_y
# time
# 1781-01-01            NaN            NaN            NaN            NaN
# 1781-01-02            NaN            NaN            NaN            NaN
# 1781-01-03            NaN            NaN            NaN            NaN
# 1781-01-04            NaN            NaN            NaN            NaN
# 1781-01-05            NaN            NaN            NaN            NaN
#
# [5 rows x 414 columns]

# %%
#%matplotlib inline

# %%
#import matplotlib.pyplot as plt

# %%
#fig = plt.figure(dpi= 136, figsize=(8,4))
#ax1 = fig.add_subplot(221)
#ax2 = fig.add_subplot(222)
#ax3 = fig.add_subplot(223)
#ax4 = fig.add_subplot(224)
#df_merged_ts[1024].plot(ax = ax1)
#df_merged_ts[1232].plot(ax = ax1)
#df_merged_ts[1246].plot(ax = ax2)
#df_merged_ts[1277].plot(ax = ax3)
#df_merged_ts[1300].plot(ax = ax4)
#plt.show()

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline

# plot
#sns.set_style('ticks')
#fig1, ax1 = plt.subplots(dpi = 400, figsize = (12,24))

#sns.heatmap(df_merged_ts, cmap='RdYlGn_r', annot=False, ax = ax1)
#sns.heatmap(df_merged_ts, cmap='coolwarm', annot=True, vmin = 8, vmax = 12, ax = ax1)

# _r reverses the normal order of the color map 'RdYlGn'

#sns.heatmap(df, cmap='coolwarm', annot=True, vmin = 8, vmax = 12, ax = ax)
#ax1.set_yticklabels(df_merged_ts.index.strftime('%Y'))
#plt.show()
#fig1.savefig('example1.png')

# %%
df_merged_ts.to_csv(local_ts_merged_dir + "ts_merged_prec.csv",sep=";")

# %%
df_merged_ts_transposed = df_merged_ts.transpose()

# %%
df_merged_ts_transposed.index.names = ['station_id']

# %%
df_merged_ts_transposed.head()
# Out:
# time           1781-01-01  1781-01-02  1781-01-03  1781-01-04  1781-01-05  \
# station_id
# stations_id_x         NaN         NaN         NaN         NaN         NaN
# stations_id_y         NaN         NaN         NaN         NaN         NaN
# stations_id_x         NaN         NaN         NaN         NaN         NaN
# stations_id_y         NaN         NaN         NaN         NaN         NaN
# stations_id_x         NaN         NaN         NaN         NaN         NaN
#
# time           1781-01-06  1781-01-07  1781-01-08  1781-01-09  1781-01-10  \
# station_id
# stations_id_x         NaN         NaN         NaN         NaN         NaN
# stations_id_y         NaN         NaN         NaN         NaN         NaN
# stations_id_x         NaN         NaN         NaN         NaN         NaN
# stations_id_y         NaN         NaN         NaN         NaN         NaN
# stations_id_x         NaN         NaN         NaN         NaN         NaN
#
# time           ...  2019-12-22  2019-12-23  2019-12-24  2019-12-25  \
# station_id     ...
# stations_id_x  ...         NaN         NaN         NaN         NaN
# stations_id_y  ...         NaN         NaN         NaN         NaN
# stations_id_x  ...        55.0        55.0        55.0        55.0
# stations_id_y  ...        57.0        57.0        57.0        57.0
# stations_id_x  ...        63.0        63.0        63.0        63.0
#
# time           2019-12-26  2019-12-27  2019-12-28  2019-12-29  2019-12-30  \
# station_id
# stations_id_x         NaN         NaN         NaN         NaN         NaN
# stations_id_y         NaN         NaN         NaN         NaN         NaN
# stations_id_x        55.0        55.0        55.0        55.0        55.0
# stations_id_y        57.0        57.0        57.0        57.0        57.0
# stations_id_x        63.0        63.0        63.0        63.0        63.0
#
# time           2019-12-31
# station_id
# stations_id_x         NaN
# stations_id_y         NaN
# stations_id_x        55.0
# stations_id_y        57.0
# stations_id_x        63.0
#
# [5 rows x 85100 columns]

# %%
df_merged_ts_transposed.to_csv(local_ts_merged_dir + "ts_merged_transposed.csv",sep=";")

# %%
def ts_append():
    # Very compact code.
    df = pd.DataFrame()
    for elt in local_zip_list:
        ffname = local_ftp_ts_dir + elt
        print("Zip archive: " + ffname)
        with ZipFile(ffname) as myzip:
            # read the time series data from the file starting with "produkt"
            prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
            print("Extract product file: %s" % prodfilename)
            print()
            with myzip.open(prodfilename) as myfile:
                dftmp = prec_ts_to_df(myfile)
                dftmp=dftmp.loc[(dftmp.index>='2016-06-01 00:00:00')&(dftmp.index<='2020-06-01 00:00:00')]
                dftmp = dftmp.merge(df_stations,how="inner",left_on="stations_id",right_on="station_id",right_index=True)
#                print(dftmp.head(5))
                df = df.append(dftmp)

    #df.index.names = ["year"]
    #df.index.rename(name = "time", inplace = True)
    return(df)

# %%
df_appended_ts = ts_append()
# Out:
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00029_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00029.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00046_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00046.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00055_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00055.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00057_19780101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19780101_20191231_00057.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00063_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00063.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00103_19780101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19780101_20191231_00103.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00118_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00118.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00128_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00128.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00142_19550101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19550101_20191231_00142.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00145_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00145.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00146_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00146.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00151_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00151.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00160_19710101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19710101_20191231_00160.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00163_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00163.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00202_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00202.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00203_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00203.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00205_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00205.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00217_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00217.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00223_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00223.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00227_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00227.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00232_19470101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19470101_20191231_00232.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00262_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00262.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00282_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00282.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00318_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00318.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00319_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00319.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00320_18790101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18790101_20191231_00320.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00323_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00323.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00349_18910901_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18910901_20191231_00349.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00359_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00359.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00360_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00360.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00376_18990101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18990101_20191231_00376.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00447_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00447.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00475_18990201_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18990201_20191231_00475.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00509_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00509.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00515_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00515.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00516_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00516.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00522_19780101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19780101_20191231_00522.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00552_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00552.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00562_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00562.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00572_19510101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19510101_20191231_00572.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00606_19500101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19500101_20191231_00606.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00647_18990101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_18990101_20191231_00647.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00653_19310101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19310101_20191231_00653.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00734_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00734.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00745_19710101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19710101_20191231_00745.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00759_19610101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19610101_20191231_00759.txt
#
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_00789_19410101_20191231_hist.zip
# Extract product file: produkt_nieder_tag_19410101_20191231_00789.txt
# Zip archive: data/original/DWD//daily/more_precip/historical/tageswerte_RR_